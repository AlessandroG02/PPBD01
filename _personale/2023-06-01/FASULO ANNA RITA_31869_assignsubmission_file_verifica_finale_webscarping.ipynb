# %% [markdown]
# # VERIFICA FINALE

# %% [markdown]
# ## Consegna
#
# Creazione di uno script in Python che esegua lo scraping dei dati dalla seguente pagina:
#
# https://www.scrapethissite.com/pages/simple/
#
# Lo script può essere scritto un file nativo di Python (formato `.py`) oppure in una cella di codice all'interno di un file di Jupyter Notebook (formato `.ipynb`).

# %% [markdown]
# ## Requisiti
#
# I moduli `requests` e `beautifulsoup4`.

# %% [markdown]
# ## Campi
#
# Ricapitolando, i dati che ti interessano sono:
#
# - Nome della nazione.
# - Capitale.
# - Popolazione.
# - Area.

# %% [markdown]
# ## Output atteso (report):
#
# Il tuo programma dovrebbe restituire come l'output (stampato a monitor) la struttura dati in cui avete immagazzinato i dati estratti.
#
# BONUS: Provare a esportare i dati estratti in CSV separato da punto e virgola.

# %% [markdown]
# ## Svolgimento

# %% [markdown]
# Scrivi lo script qua sotto e consegna questo file, altrimenti crea un nuovo file `.py` e consegna lo script.

# %%
# scrivi qui
import requests
from bs4 import BeautifulSoup
from pprint import pprint

url_list = [
    'https://www.scrapethissite.com/pages/simple/'
   
]

result = requests.get(url_list[0])

if result.status_code == 200:
    soup = BeautifulSoup(result.content, 'html.parser')

    nations = soup.select('div.country')
    
   
    items = []
    #*
    for adv in nations:
        data = { 
            'nations': adv.select('h3.country-name')[0].get_text().strip(),
            'capital': adv.select('span.country-capital')[0].get_text().strip(),
            'population': adv.select('span.country-population')[0].get_text().strip(),
            'country_area': adv.select('span.country-area')[0].get_text().strip(),
        }  

        items.append(data)

    pprint(items)
# Out:
# [{'capital': 'Andorra la Vella',
#   'country_area': '468.0',
#   'nations': 'Andorra',
#   'population': '84000'},
#  {'capital': 'Abu Dhabi',
#   'country_area': '82880.0',
#   'nations': 'United Arab Emirates',
#   'population': '4975593'},
#  {'capital': 'Kabul',
#   'country_area': '647500.0',
#   'nations': 'Afghanistan',
#   'population': '29121286'},
#  {'capital': "St. John's",
#   'country_area': '443.0',
#   'nations': 'Antigua and Barbuda',
#   'population': '86754'},
#  {'capital': 'The Valley',
#   'country_area': '102.0',
#   'nations': 'Anguilla',
#   'population': '13254'},
#  {'capital': 'Tirana',
#   'country_area': '28748.0',
#   'nations': 'Albania',
#   'population': '2986952'},
#  {'capital': 'Yerevan',
#   'country_area': '29800.0',
#   'nations': 'Armenia',
#   'population': '2968000'},
#  {'capital': 'Luanda',
#   'country_area': '1246700.0',
#   'nations': 'Angola',
#   'population': '13068161'},
#  {'capital': 'None',
#   'country_area': '1.4E7',
#   'nations': 'Antarctica',
#   'population': '0'},
#  {'capital': 'Buenos Aires',
#   'country_area': '2766890.0',
#   'nations': 'Argentina',
#   'population': '41343201'},
#  {'capital': 'Pago Pago',
#   'country_area': '199.0',
#   'nations': 'American Samoa',
#   'population': '57881'},
#  {'capital': 'Vienna',
#   'country_area': '83858.0',
#   'nations': 'Austria',
#   'population': '8205000'},
#  {'capital': 'Canberra',
#   'country_area': '7686850.0',
#   'nations': 'Australia',
#   'population': '21515754'},
#  {'capital': 'Oranjestad',
#   'country_area': '193.0',
#   'nations': 'Aruba',
#   'population': '71566'},
#  {'capital': 'Mariehamn',
#   'country_area': '1580.0',
#   'nations': 'Åland',
#   'population': '26711'},
#  {'capital': 'Baku',
#   'country_area': '86600.0',
#   'nations': 'Azerbaijan',
#   'population': '8303512'},
#  {'capital': 'Sarajevo',
#   'country_area': '51129.0',
#   'nations': 'Bosnia and Herzegovina',
#   'population': '4590000'},
#  {'capital': 'Bridgetown',
#   'country_area': '431.0',
#   'nations': 'Barbados',
#   'population': '285653'},
#  {'capital': 'Dhaka',
#   'country_area': '144000.0',
#   'nations': 'Bangladesh',
#   'population': '156118464'},
#  {'capital': 'Brussels',
#   'country_area': '30510.0',
#   'nations': 'Belgium',
#   'population': '10403000'},
#  {'capital': 'Ouagadougou',
#   'country_area': '274200.0',
#   'nations': 'Burkina Faso',
#   'population': '16241811'},
#  {'capital': 'Sofia',
#   'country_area': '110910.0',
#   'nations': 'Bulgaria',
#   'population': '7148785'},
#  {'capital': 'Manama',
#   'country_area': '665.0',
#   'nations': 'Bahrain',
#   'population': '738004'},
#  {'capital': 'Bujumbura',
#   'country_area': '27830.0',
#   'nations': 'Burundi',
#   'population': '9863117'},
#  {'capital': 'Porto-Novo',
#   'country_area': '112620.0',
#   'nations': 'Benin',
#   'population': '9056010'},
#  {'capital': 'Gustavia',
#   'country_area': '21.0',
#   'nations': 'Saint Barthélemy',
#   'population': '8450'},
#  {'capital': 'Hamilton',
#   'country_area': '53.0',
#   'nations': 'Bermuda',
#   'population': '65365'},
#  {'capital': 'Bandar Seri Begawan',
#   'country_area': '5770.0',
#   'nations': 'Brunei',
#   'population': '395027'},
#  {'capital': 'Sucre',
#   'country_area': '1098580.0',
#   'nations': 'Bolivia',
#   'population': '9947418'},
#  {'capital': 'Kralendijk',
#   'country_area': '328.0',
#   'nations': 'Bonaire',
#   'population': '18012'},
#  {'capital': 'Brasília',
#   'country_area': '8511965.0',
#   'nations': 'Brazil',
#   'population': '201103330'},
#  {'capital': 'Nassau',
#   'country_area': '13940.0',
#   'nations': 'Bahamas',
#   'population': '301790'},
#  {'capital': 'Thimphu',
#   'country_area': '47000.0',
#   'nations': 'Bhutan',
#   'population': '699847'},
#  {'capital': 'None',
#   'country_area': '49.0',
#   'nations': 'Bouvet Island',
#   'population': '0'},
#  {'capital': 'Gaborone',
#   'country_area': '600370.0',
#   'nations': 'Botswana',
#   'population': '2029307'},
#  {'capital': 'Minsk',
#   'country_area': '207600.0',
#   'nations': 'Belarus',
#   'population': '9685000'},
#  {'capital': 'Belmopan',
#   'country_area': '22966.0',
#   'nations': 'Belize',
#   'population': '314522'},
#  {'capital': 'Ottawa',
#   'country_area': '9984670.0',
#   'nations': 'Canada',
#   'population': '33679000'},
#  {'capital': 'West Island',
#   'country_area': '14.0',
#   'nations': 'Cocos [Keeling] Islands',
#   'population': '628'},
#  {'capital': 'Kinshasa',
#   'country_area': '2345410.0',
#   'nations': 'Democratic Republic of the Congo',
#   'population': '70916439'},
#  {'capital': 'Bangui',
#   'country_area': '622984.0',
#   'nations': 'Central African Republic',
#   'population': '4844927'},
#  {'capital': 'Brazzaville',
#   'country_area': '342000.0',
#   'nations': 'Republic of the Congo',
#   'population': '3039126'},
#  {'capital': 'Bern',
#   'country_area': '41290.0',
#   'nations': 'Switzerland',
#   'population': '7581000'},
#  {'capital': 'Yamoussoukro',
#   'country_area': '322460.0',
#   'nations': 'Ivory Coast',
#   'population': '21058798'},
#  {'capital': 'Avarua',
#   'country_area': '240.0',
#   'nations': 'Cook Islands',
#   'population': '21388'},
#  {'capital': 'Santiago',
#   'country_area': '756950.0',
#   'nations': 'Chile',
#   'population': '16746491'},
#  {'capital': 'Yaoundé',
#   'country_area': '475440.0',
#   'nations': 'Cameroon',
#   'population': '19294149'},
#  {'capital': 'Beijing',
#   'country_area': '9596960.0',
#   'nations': 'China',
#   'population': '1330044000'},
#  {'capital': 'Bogotá',
#   'country_area': '1138910.0',
#   'nations': 'Colombia',
#   'population': '47790000'},
#  {'capital': 'San José',
#   'country_area': '51100.0',
#   'nations': 'Costa Rica',
#   'population': '4516220'},
#  {'capital': 'Havana',
#   'country_area': '110860.0',
#   'nations': 'Cuba',
#   'population': '11423000'},
#  {'capital': 'Praia',
#   'country_area': '4033.0',
#   'nations': 'Cape Verde',
#   'population': '508659'},
#  {'capital': 'Willemstad',
#   'country_area': '444.0',
#   'nations': 'Curacao',
#   'population': '141766'},
#  {'capital': 'Flying Fish Cove',
#   'country_area': '135.0',
#   'nations': 'Christmas Island',
#   'population': '1500'},
#  {'capital': 'Nicosia',
#   'country_area': '9250.0',
#   'nations': 'Cyprus',
#   'population': '1102677'},
#  {'capital': 'Prague',
#   'country_area': '78866.0',
#   'nations': 'Czech Republic',
#   'population': '10476000'},
#  {'capital': 'Berlin',
#   'country_area': '357021.0',
#   'nations': 'Germany',
#   'population': '81802257'},
#  {'capital': 'Djibouti',
#   'country_area': '23000.0',
#   'nations': 'Djibouti',
#   'population': '740528'},
#  {'capital': 'Copenhagen',
#   'country_area': '43094.0',
#   'nations': 'Denmark',
#   'population': '5484000'},
#  {'capital': 'Roseau',
#   'country_area': '754.0',
#   'nations': 'Dominica',
#   'population': '72813'},
#  {'capital': 'Santo Domingo',
#   'country_area': '48730.0',
#   'nations': 'Dominican Republic',
#   'population': '9823821'},
#  {'capital': 'Algiers',
#   'country_area': '2381740.0',
#   'nations': 'Algeria',
#   'population': '34586184'},
#  {'capital': 'Quito',
#   'country_area': '283560.0',
#   'nations': 'Ecuador',
#   'population': '14790608'},
#  {'capital': 'Tallinn',
#   'country_area': '45226.0',
#   'nations': 'Estonia',
#   'population': '1291170'},
#  {'capital': 'Cairo',
#   'country_area': '1001450.0',
#   'nations': 'Egypt',
#   'population': '80471869'},
#  {'capital': 'Laâyoune / El Aaiún',
#   'country_area': '266000.0',
#   'nations': 'Western Sahara',
#   'population': '273008'},
#  {'capital': 'Asmara',
#   'country_area': '121320.0',
#   'nations': 'Eritrea',
#   'population': '5792984'},
#  {'capital': 'Madrid',
#   'country_area': '504782.0',
#   'nations': 'Spain',
#   'population': '46505963'},
#  {'capital': 'Addis Ababa',
#   'country_area': '1127127.0',
#   'nations': 'Ethiopia',
#   'population': '88013491'},
#  {'capital': 'Helsinki',
#   'country_area': '337030.0',
#   'nations': 'Finland',
#   'population': '5244000'},
#  {'capital': 'Suva',
#   'country_area': '18270.0',
#   'nations': 'Fiji',
#   'population': '875983'},
#  {'capital': 'Stanley',
#   'country_area': '12173.0',
#   'nations': 'Falkland Islands',
#   'population': '2638'},
#  {'capital': 'Palikir',
#   'country_area': '702.0',
#   'nations': 'Micronesia',
#   'population': '107708'},
#  {'capital': 'Tórshavn',
#   'country_area': '1399.0',
#   'nations': 'Faroe Islands',
#   'population': '48228'},
#  {'capital': 'Paris',
#   'country_area': '547030.0',
#   'nations': 'France',
#   'population': '64768389'},
#  {'capital': 'Libreville',
#   'country_area': '267667.0',
#   'nations': 'Gabon',
#   'population': '1545255'},
#  {'capital': 'London',
#   'country_area': '244820.0',
#   'nations': 'United Kingdom',
#   'population': '62348447'},
#  {'capital': "St. George's",
#   'country_area': '344.0',
#   'nations': 'Grenada',
#   'population': '107818'},
#  {'capital': 'Tbilisi',
#   'country_area': '69700.0',
#   'nations': 'Georgia',
#   'population': '4630000'},
#  {'capital': 'Cayenne',
#   'country_area': '91000.0',
#   'nations': 'French Guiana',
#   'population': '195506'},
#  {'capital': 'St Peter Port',
#   'country_area': '78.0',
#   'nations': 'Guernsey',
#   'population': '65228'},
#  {'capital': 'Accra',
#   'country_area': '239460.0',
#   'nations': 'Ghana',
#   'population': '24339838'},
#  {'capital': 'Gibraltar',
#   'country_area': '6.5',
#   'nations': 'Gibraltar',
#   'population': '27884'},
#  {'capital': 'Nuuk',
#   'country_area': '2166086.0',
#   'nations': 'Greenland',
#   'population': '56375'},
#  {'capital': 'Bathurst',
#   'country_area': '11300.0',
#   'nations': 'Gambia',
#   'population': '1593256'},
#  {'capital': 'Conakry',
#   'country_area': '245857.0',
#   'nations': 'Guinea',
#   'population': '10324025'},
#  {'capital': 'Basse-Terre',
#   'country_area': '1780.0',
#   'nations': 'Guadeloupe',
#   'population': '443000'},
#  {'capital': 'Malabo',
#   'country_area': '28051.0',
#   'nations': 'Equatorial Guinea',
#   'population': '1014999'},
#  {'capital': 'Athens',
#   'country_area': '131940.0',
#   'nations': 'Greece',
#   'population': '11000000'},
#  {'capital': 'Grytviken',
#   'country_area': '3903.0',
#   'nations': 'South Georgia and the South Sandwich Islands',
#   'population': '30'},
#  {'capital': 'Guatemala City',
#   'country_area': '108890.0',
#   'nations': 'Guatemala',
#   'population': '13550440'},
#  {'capital': 'Hagåtña',
#   'country_area': '549.0',
#   'nations': 'Guam',
#   'population': '159358'},
#  {'capital': 'Bissau',
#   'country_area': '36120.0',
#   'nations': 'Guinea-Bissau',
#   'population': '1565126'},
#  {'capital': 'Georgetown',
#   'country_area': '214970.0',
#   'nations': 'Guyana',
#   'population': '748486'},
#  {'capital': 'Hong Kong',
#   'country_area': '1092.0',
#   'nations': 'Hong Kong',
#   'population': '6898686'},
#  {'capital': 'None',
#   'country_area': '412.0',
#   'nations': 'Heard Island and McDonald Islands',
#   'population': '0'},
#  {'capital': 'Tegucigalpa',
#   'country_area': '112090.0',
#   'nations': 'Honduras',
#   'population': '7989415'},
#  {'capital': 'Zagreb',
#   'country_area': '56542.0',
#   'nations': 'Croatia',
#   'population': '4491000'},
#  {'capital': 'Port-au-Prince',
#   'country_area': '27750.0',
#   'nations': 'Haiti',
#   'population': '9648924'},
#  {'capital': 'Budapest',
#   'country_area': '93030.0',
#   'nations': 'Hungary',
#   'population': '9982000'},
#  {'capital': 'Jakarta',
#   'country_area': '1919440.0',
#   'nations': 'Indonesia',
#   'population': '242968342'},
#  {'capital': 'Dublin',
#   'country_area': '70280.0',
#   'nations': 'Ireland',
#   'population': '4622917'},
#  {'capital': 'None',
#   'country_area': '20770.0',
#   'nations': 'Israel',
#   'population': '7353985'},
#  {'capital': 'Douglas',
#   'country_area': '572.0',
#   'nations': 'Isle of Man',
#   'population': '75049'},
#  {'capital': 'New Delhi',
#   'country_area': '3287590.0',
#   'nations': 'India',
#   'population': '1173108018'},
#  {'capital': 'None',
#   'country_area': '60.0',
#   'nations': 'British Indian Ocean Territory',
#   'population': '4000'},
#  {'capital': 'Baghdad',
#   'country_area': '437072.0',
#   'nations': 'Iraq',
#   'population': '29671605'},
#  {'capital': 'Tehran',
#   'country_area': '1648000.0',
#   'nations': 'Iran',
#   'population': '76923300'},
#  {'capital': 'Reykjavik',
#   'country_area': '103000.0',
#   'nations': 'Iceland',
#   'population': '308910'},
#  {'capital': 'Rome',
#   'country_area': '301230.0',
#   'nations': 'Italy',
#   'population': '60340328'},
#  {'capital': 'Saint Helier',
#   'country_area': '116.0',
#   'nations': 'Jersey',
#   'population': '90812'},
#  {'capital': 'Kingston',
#   'country_area': '10991.0',
#   'nations': 'Jamaica',
#   'population': '2847232'},
#  {'capital': 'Amman',
#   'country_area': '92300.0',
#   'nations': 'Jordan',
#   'population': '6407085'},
#  {'capital': 'Tokyo',
#   'country_area': '377835.0',
#   'nations': 'Japan',
#   'population': '127288000'},
#  {'capital': 'Nairobi',
#   'country_area': '582650.0',
#   'nations': 'Kenya',
#   'population': '40046566'},
#  {'capital': 'Bishkek',
#   'country_area': '198500.0',
#   'nations': 'Kyrgyzstan',
#   'population': '5776500'},
#  {'capital': 'Phnom Penh',
#   'country_area': '181040.0',
#   'nations': 'Cambodia',
#   'population': '14453680'},
#  {'capital': 'Tarawa',
#   'country_area': '811.0',
#   'nations': 'Kiribati',
#   'population': '92533'},
#  {'capital': 'Moroni',
#   'country_area': '2170.0',
#   'nations': 'Comoros',
#   'population': '773407'},
#  {'capital': 'Basseterre',
#   'country_area': '261.0',
#   'nations': 'Saint Kitts and Nevis',
#   'population': '51134'},
#  {'capital': 'Pyongyang',
#   'country_area': '120540.0',
#   'nations': 'North Korea',
#   'population': '22912177'},
#  {'capital': 'Seoul',
#   'country_area': '98480.0',
#   'nations': 'South Korea',
#   'population': '48422644'},
#  {'capital': 'Kuwait City',
#   'country_area': '17820.0',
#   'nations': 'Kuwait',
#   'population': '2789132'},
#  {'capital': 'George Town',
#   'country_area': '262.0',
#   'nations': 'Cayman Islands',
#   'population': '44270'},
#  {'capital': 'Astana',
#   'country_area': '2717300.0',
#   'nations': 'Kazakhstan',
#   'population': '15340000'},
#  {'capital': 'Vientiane',
#   'country_area': '236800.0',
#   'nations': 'Laos',
#   'population': '6368162'},
#  {'capital': 'Beirut',
#   'country_area': '10400.0',
#   'nations': 'Lebanon',
#   'population': '4125247'},
#  {'capital': 'Castries',
#   'country_area': '616.0',
#   'nations': 'Saint Lucia',
#   'population': '160922'},
#  {'capital': 'Vaduz',
#   'country_area': '160.0',
#   'nations': 'Liechtenstein',
#   'population': '35000'},
#  {'capital': 'Colombo',
#   'country_area': '65610.0',
#   'nations': 'Sri Lanka',
#   'population': '21513990'},
#  {'capital': 'Monrovia',
#   'country_area': '111370.0',
#   'nations': 'Liberia',
#   'population': '3685076'},
#  {'capital': 'Maseru',
#   'country_area': '30355.0',
#   'nations': 'Lesotho',
#   'population': '1919552'},
#  {'capital': 'Vilnius',
#   'country_area': '65200.0',
#   'nations': 'Lithuania',
#   'population': '2944459'},
#  {'capital': 'Luxembourg',
#   'country_area': '2586.0',
#   'nations': 'Luxembourg',
#   'population': '497538'},
#  {'capital': 'Riga',
#   'country_area': '64589.0',
#   'nations': 'Latvia',
#   'population': '2217969'},
#  {'capital': 'Tripoli',
#   'country_area': '1759540.0',
#   'nations': 'Libya',
#   'population': '6461454'},
#  {'capital': 'Rabat',
#   'country_area': '446550.0',
#   'nations': 'Morocco',
#   'population': '31627428'},
#  {'capital': 'Monaco',
#   'country_area': '1.95',
#   'nations': 'Monaco',
#   'population': '32965'},
#  {'capital': 'Chişinău',
#   'country_area': '33843.0',
#   'nations': 'Moldova',
#   'population': '4324000'},
#  {'capital': 'Podgorica',
#   'country_area': '14026.0',
#   'nations': 'Montenegro',
#   'population': '666730'},
#  {'capital': 'Marigot',
#   'country_area': '53.0',
#   'nations': 'Saint Martin',
#   'population': '35925'},
#  {'capital': 'Antananarivo',
#   'country_area': '587040.0',
#   'nations': 'Madagascar',
#   'population': '21281844'},
#  {'capital': 'Majuro',
#   'country_area': '181.3',
#   'nations': 'Marshall Islands',
#   'population': '65859'},
#  {'capital': 'Skopje',
#   'country_area': '25333.0',
#   'nations': 'Macedonia',
#   'population': '2062294'},
#  {'capital': 'Bamako',
#   'country_area': '1240000.0',
#   'nations': 'Mali',
#   'population': '13796354'},
#  {'capital': 'Naypyitaw',
#   'country_area': '678500.0',
#   'nations': 'Myanmar [Burma]',
#   'population': '53414374'},
#  {'capital': 'Ulan Bator',
#   'country_area': '1565000.0',
#   'nations': 'Mongolia',
#   'population': '3086918'},
#  {'capital': 'Macao',
#   'country_area': '254.0',
#   'nations': 'Macao',
#   'population': '449198'},
#  {'capital': 'Saipan',
#   'country_area': '477.0',
#   'nations': 'Northern Mariana Islands',
#   'population': '53883'},
#  {'capital': 'Fort-de-France',
#   'country_area': '1100.0',
#   'nations': 'Martinique',
#   'population': '432900'},
#  {'capital': 'Nouakchott',
#   'country_area': '1030700.0',
#   'nations': 'Mauritania',
#   'population': '3205060'},
#  {'capital': 'Plymouth',
#   'country_area': '102.0',
#   'nations': 'Montserrat',
#   'population': '9341'},
#  {'capital': 'Valletta',
#   'country_area': '316.0',
#   'nations': 'Malta',
#   'population': '403000'},
#  {'capital': 'Port Louis',
#   'country_area': '2040.0',
#   'nations': 'Mauritius',
#   'population': '1294104'},
#  {'capital': 'Malé',
#   'country_area': '300.0',
#   'nations': 'Maldives',
#   'population': '395650'},
#  {'capital': 'Lilongwe',
#   'country_area': '118480.0',
#   'nations': 'Malawi',
#   'population': '15447500'},
#  {'capital': 'Mexico City',
#   'country_area': '1972550.0',
#   'nations': 'Mexico',
#   'population': '112468855'},
#  {'capital': 'Kuala Lumpur',
#   'country_area': '329750.0',
#   'nations': 'Malaysia',
#   'population': '28274729'},
#  {'capital': 'Maputo',
#   'country_area': '801590.0',
#   'nations': 'Mozambique',
#   'population': '22061451'},
#  {'capital': 'Windhoek',
#   'country_area': '825418.0',
#   'nations': 'Namibia',
#   'population': '2128471'},
#  {'capital': 'Noumea',
#   'country_area': '19060.0',
#   'nations': 'New Caledonia',
#   'population': '216494'},
#  {'capital': 'Niamey',
#   'country_area': '1267000.0',
#   'nations': 'Niger',
#   'population': '15878271'},
#  {'capital': 'Kingston',
#   'country_area': '34.6',
#   'nations': 'Norfolk Island',
#   'population': '1828'},
#  {'capital': 'Abuja',
#   'country_area': '923768.0',
#   'nations': 'Nigeria',
#   'population': '154000000'},
#  {'capital': 'Managua',
#   'country_area': '129494.0',
#   'nations': 'Nicaragua',
#   'population': '5995928'},
#  {'capital': 'Amsterdam',
#   'country_area': '41526.0',
#   'nations': 'Netherlands',
#   'population': '16645000'},
#  {'capital': 'Oslo',
#   'country_area': '324220.0',
#   'nations': 'Norway',
#   'population': '5009150'},
#  {'capital': 'Kathmandu',
#   'country_area': '140800.0',
#   'nations': 'Nepal',
#   'population': '28951852'},
#  {'capital': 'Yaren',
#   'country_area': '21.0',
#   'nations': 'Nauru',
#   'population': '10065'},
#  {'capital': 'Alofi',
#   'country_area': '260.0',
#   'nations': 'Niue',
#   'population': '2166'},
#  {'capital': 'Wellington',
#   'country_area': '268680.0',
#   'nations': 'New Zealand',
#   'population': '4252277'},
#  {'capital': 'Muscat',
#   'country_area': '212460.0',
#   'nations': 'Oman',
#   'population': '2967717'},
#  {'capital': 'Panama City',
#   'country_area': '78200.0',
#   'nations': 'Panama',
#   'population': '3410676'},
#  {'capital': 'Lima',
#   'country_area': '1285220.0',
#   'nations': 'Peru',
#   'population': '29907003'},
#  {'capital': 'Papeete',
#   'country_area': '4167.0',
#   'nations': 'French Polynesia',
#   'population': '270485'},
#  {'capital': 'Port Moresby',
#   'country_area': '462840.0',
#   'nations': 'Papua New Guinea',
#   'population': '6064515'},
#  {'capital': 'Manila',
#   'country_area': '300000.0',
#   'nations': 'Philippines',
#   'population': '99900177'},
#  {'capital': 'Islamabad',
#   'country_area': '803940.0',
#   'nations': 'Pakistan',
#   'population': '184404791'},
#  {'capital': 'Warsaw',
#   'country_area': '312685.0',
#   'nations': 'Poland',
#   'population': '38500000'},
#  {'capital': 'Saint-Pierre',
#   'country_area': '242.0',
#   'nations': 'Saint Pierre and Miquelon',
#   'population': '7012'},
#  {'capital': 'Adamstown',
#   'country_area': '47.0',
#   'nations': 'Pitcairn Islands',
#   'population': '46'},
#  {'capital': 'San Juan',
#   'country_area': '9104.0',
#   'nations': 'Puerto Rico',
#   'population': '3916632'},
#  {'capital': 'None',
#   'country_area': '5970.0',
#   'nations': 'Palestine',
#   'population': '3800000'},
#  {'capital': 'Lisbon',
#   'country_area': '92391.0',
#   'nations': 'Portugal',
#   'population': '10676000'},
#  {'capital': 'Melekeok',
#   'country_area': '458.0',
#   'nations': 'Palau',
#   'population': '19907'},
#  {'capital': 'Asunción',
#   'country_area': '406750.0',
#   'nations': 'Paraguay',
#   'population': '6375830'},
#  {'capital': 'Doha',
#   'country_area': '11437.0',
#   'nations': 'Qatar',
#   'population': '840926'},
#  {'capital': 'Saint-Denis',
#   'country_area': '2517.0',
#   'nations': 'Réunion',
#   'population': '776948'},
#  {'capital': 'Bucharest',
#   'country_area': '237500.0',
#   'nations': 'Romania',
#   'population': '21959278'},
#  {'capital': 'Belgrade',
#   'country_area': '88361.0',
#   'nations': 'Serbia',
#   'population': '7344847'},
#  {'capital': 'Moscow',
#   'country_area': '1.71E7',
#   'nations': 'Russia',
#   'population': '140702000'},
#  {'capital': 'Kigali',
#   'country_area': '26338.0',
#   'nations': 'Rwanda',
#   'population': '11055976'},
#  {'capital': 'Riyadh',
#   'country_area': '1960582.0',
#   'nations': 'Saudi Arabia',
#   'population': '25731776'},
#  {'capital': 'Honiara',
#   'country_area': '28450.0',
#   'nations': 'Solomon Islands',
#   'population': '559198'},
#  {'capital': 'Victoria',
#   'country_area': '455.0',
#   'nations': 'Seychelles',
#   'population': '88340'},
#  {'capital': 'Khartoum',
#   'country_area': '1861484.0',
#   'nations': 'Sudan',
#   'population': '35000000'},
#  {'capital': 'Stockholm',
#   'country_area': '449964.0',
#   'nations': 'Sweden',
#   'population': '9828655'},
#  {'capital': 'Singapore',
#   'country_area': '692.7',
#   'nations': 'Singapore',
#   'population': '4701069'},
#  {'capital': 'Jamestown',
#   'country_area': '410.0',
#   'nations': 'Saint Helena',
#   'population': '7460'},
#  {'capital': 'Ljubljana',
#   'country_area': '20273.0',
#   'nations': 'Slovenia',
#   'population': '2007000'},
#  {'capital': 'Longyearbyen',
#   'country_area': '62049.0',
#   'nations': 'Svalbard and Jan Mayen',
#   'population': '2550'},
#  {'capital': 'Bratislava',
#   'country_area': '48845.0',
#   'nations': 'Slovakia',
#   'population': '5455000'},
#  {'capital': 'Freetown',
#   'country_area': '71740.0',
#   'nations': 'Sierra Leone',
#   'population': '5245695'},
#  {'capital': 'San Marino',
#   'country_area': '61.2',
#   'nations': 'San Marino',
#   'population': '31477'},
#  {'capital': 'Dakar',
#   'country_area': '196190.0',
#   'nations': 'Senegal',
#   'population': '12323252'},
#  {'capital': 'Mogadishu',
#   'country_area': '637657.0',
#   'nations': 'Somalia',
#   'population': '10112453'},
#  {'capital': 'Paramaribo',
#   'country_area': '163270.0',
#   'nations': 'Suriname',
#   'population': '492829'},
#  {'capital': 'Juba',
#   'country_area': '644329.0',
#   'nations': 'South Sudan',
#   'population': '8260490'},
#  {'capital': 'São Tomé',
#   'country_area': '1001.0',
#   'nations': 'São Tomé and Príncipe',
#   'population': '175808'},
#  {'capital': 'San Salvador',
#   'country_area': '21040.0',
#   'nations': 'El Salvador',
#   'population': '6052064'},
#  {'capital': 'Philipsburg',
#   'country_area': '21.0',
#   'nations': 'Sint Maarten',
#   'population': '37429'},
#  {'capital': 'Damascus',
#   'country_area': '185180.0',
#   'nations': 'Syria',
#   'population': '22198110'},
#  {'capital': 'Mbabane',
#   'country_area': '17363.0',
#   'nations': 'Swaziland',
#   'population': '1354051'},
#  {'capital': 'Cockburn Town',
#   'country_area': '430.0',
#   'nations': 'Turks and Caicos Islands',
#   'population': '20556'},
#  {'capital': "N'Djamena",
#   'country_area': '1284000.0',
#   'nations': 'Chad',
#   'population': '10543464'},
#  {'capital': 'Port-aux-Français',
#   'country_area': '7829.0',
#   'nations': 'French Southern Territories',
#   'population': '140'},
#  {'capital': 'Lomé',
#   'country_area': '56785.0',
#   'nations': 'Togo',
#   'population': '6587239'},
#  {'capital': 'Bangkok',
#   'country_area': '514000.0',
#   'nations': 'Thailand',
#   'population': '67089500'},
#  {'capital': 'Dushanbe',
#   'country_area': '143100.0',
#   'nations': 'Tajikistan',
#   'population': '7487489'},
#  {'capital': 'None',
#   'country_area': '10.0',
#   'nations': 'Tokelau',
#   'population': '1466'},
#  {'capital': 'Dili',
#   'country_area': '15007.0',
#   'nations': 'East Timor',
#   'population': '1154625'},
#  {'capital': 'Ashgabat',
#   'country_area': '488100.0',
#   'nations': 'Turkmenistan',
#   'population': '4940916'},
#  {'capital': 'Tunis',
#   'country_area': '163610.0',
#   'nations': 'Tunisia',
#   'population': '10589025'},
#  {'capital': "Nuku'alofa",
#   'country_area': '748.0',
#   'nations': 'Tonga',
#   'population': '122580'},
#  {'capital': 'Ankara',
#   'country_area': '780580.0',
#   'nations': 'Turkey',
#   'population': '77804122'},
#  {'capital': 'Port of Spain',
#   'country_area': '5128.0',
#   'nations': 'Trinidad and Tobago',
#   'population': '1228691'},
#  {'capital': 'Funafuti',
#   'country_area': '26.0',
#   'nations': 'Tuvalu',
#   'population': '10472'},
#  {'capital': 'Taipei',
#   'country_area': '35980.0',
#   'nations': 'Taiwan',
#   'population': '22894384'},
#  {'capital': 'Dodoma',
#   'country_area': '945087.0',
#   'nations': 'Tanzania',
#   'population': '41892895'},
#  {'capital': 'Kiev',
#   'country_area': '603700.0',
#   'nations': 'Ukraine',
#   'population': '45415596'},
#  {'capital': 'Kampala',
#   'country_area': '236040.0',
#   'nations': 'Uganda',
#   'population': '33398682'},
#  {'capital': 'None',
#   'country_area': '0.0',
#   'nations': 'U.S. Minor Outlying Islands',
#   'population': '0'},
#  {'capital': 'Washington',
#   'country_area': '9629091.0',
#   'nations': 'United States',
#   'population': '310232863'},
#  {'capital': 'Montevideo',
#   'country_area': '176220.0',
#   'nations': 'Uruguay',
#   'population': '3477000'},
#  {'capital': 'Tashkent',
#   'country_area': '447400.0',
#   'nations': 'Uzbekistan',
#   'population': '27865738'},
#  {'capital': 'Vatican City',
#   'country_area': '0.44',
#   'nations': 'Vatican City',
#   'population': '921'},
#  {'capital': 'Kingstown',
#   'country_area': '389.0',
#   'nations': 'Saint Vincent and the Grenadines',
#   'population': '104217'},
#  {'capital': 'Caracas',
#   'country_area': '912050.0',
#   'nations': 'Venezuela',
#   'population': '27223228'},
#  {'capital': 'Road Town',
#   'country_area': '153.0',
#   'nations': 'British Virgin Islands',
#   'population': '21730'},
#  {'capital': 'Charlotte Amalie',
#   'country_area': '352.0',
#   'nations': 'U.S. Virgin Islands',
#   'population': '108708'},
#  {'capital': 'Hanoi',
#   'country_area': '329560.0',
#   'nations': 'Vietnam',
#   'population': '89571130'},
#  {'capital': 'Port Vila',
#   'country_area': '12200.0',
#   'nations': 'Vanuatu',
#   'population': '221552'},
#  {'capital': 'Mata-Utu',
#   'country_area': '274.0',
#   'nations': 'Wallis and Futuna',
#   'population': '16025'},
#  {'capital': 'Apia',
#   'country_area': '2944.0',
#   'nations': 'Samoa',
#   'population': '192001'},
#  {'capital': 'Pristina',
#   'country_area': '10908.0',
#   'nations': 'Kosovo',
#   'population': '1800000'},
#  {'capital': 'Sanaa',
#   'country_area': '527970.0',
#   'nations': 'Yemen',
#   'population': '23495361'},
#  {'capital': 'Mamoudzou',
#   'country_area': '374.0',
#   'nations': 'Mayotte',
#   'population': '159042'},
#  {'capital': 'Pretoria',
#   'country_area': '1219912.0',
#   'nations': 'South Africa',
#   'population': '49000000'},
#  {'capital': 'Lusaka',
#   'country_area': '752614.0',
#   'nations': 'Zambia',
#   'population': '13460305'},
#  {'capital': 'Harare',
#   'country_area': '390580.0',
#   'nations': 'Zimbabwe',
#   'population': '11651858'}]
